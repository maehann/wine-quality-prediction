# %% [markdown]
# # پروژه پیش‌بینی کیفیت شراب
# ## مرحله ۱: شناخت داده
#
# هدف: بررسی ساختار دیتاست و نوع داده‌ها

# %%
import pandas as pd
import numpy as np

print('کتابخانه‌ها با موفقیت بارگذاری شدند')
